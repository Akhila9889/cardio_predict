# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Akhila\AI\cardio_train.csv") #data accessing
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
# !pip install pandas

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df.tail()
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 69995      1     0       1       0
# 69996      0     0       1       1
# 69997      0     1       0       1
# 69998      0     0       0       1
# 69999      0     0       1       0

# %%
df[4:21]
# Out:
#     id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 4    4  17474       1     156    56.0    100     60            1     1      0
# 5    8  21914       1     151    67.0    120     80            2     2      0
# 6    9  22113       1     157    93.0    130     80            3     1      0
# 7   12  22584       2     178    95.0    130     90            3     3      0
# 8   13  17668       1     158    71.0    110     70            1     1      0
# 9   14  19834       1     164    68.0    110     60            1     1      0
# 10  15  22530       1     169    80.0    120     80            1     1      0
# 11  16  18815       2     173    60.0    120     80            1     1      0
# 12  18  14791       2     165    60.0    120     80            1     1      0
# 13  21  19809       1     158    78.0    110     70            1     1      0
# 14  23  14532       2     181    95.0    130     90            1     1      1
# ...

# %%
df1=pd.read_csv(r"C:\Users\Akhila\AI\cardio_train.csv",skiprows=[0,2])
df1
# Out:
#            0  18393  2  168     62  110   80  1  1.1  0.1  0.2  1.2  0.3
# 0          2  18857  1  165   64.0  130   70  3    1    0    0    0    1
# 1          3  17623  2  169   82.0  150  100  1    1    0    0    1    1
# 2          4  17474  1  156   56.0  100   60  1    1    0    0    0    0
# 3          8  21914  1  151   67.0  120   80  2    2    0    0    0    0
# 4          9  22113  1  157   93.0  130   80  3    1    0    0    1    0
# ...      ...    ... ..  ...    ...  ...  ... ..  ...  ...  ...  ...  ...
# 69993  99993  19240  2  168   76.0  120   80  1    1    1    0    1    0
# 69994  99995  22601  1  158  126.0  140   90  2    2    0    0    1    1
# 69995  99996  19066  2  183  105.0  180   90  3    1    0    1    0    1
# 69996  99998  22431  1  163   72.0  135   80  1    2    0    0    0    1
# 69997  99999  20540  1  170   72.0  120   80  2    1    0    0    1    0
#
# [69998 rows x 13 columns]

# %%
df2=pd.read_csv(r"C:\Users\Akhila\AI\cardio_train.csv",index_col="height")
df2
# Out:
#            id    age  gender  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# height
# 168         0  18393       2    62.0    110     80            1     1      0
# 156         1  20228       1    85.0    140     90            3     1      0
# 165         2  18857       1    64.0    130     70            3     1      0
# 169         3  17623       2    82.0    150    100            1     1      0
# 156         4  17474       1    56.0    100     60            1     1      0
# ...       ...    ...     ...     ...    ...    ...          ...   ...    ...
# 168     99993  19240       2    76.0    120     80            1     1      1
# 158     99995  22601       1   126.0    140     90            2     2      0
# 183     99996  19066       2   105.0    180     90            3     1      0
# 163     99998  22431       1    72.0    135     80            1     2      0
# 170     99999  20540       1    72.0    120     80            2     1      0
#
#         alco  active  cardio
# ...

# %%
df.sort_index()
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.sort_index(ascending=False)
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
print(df["weight"][4])
# Out:
# 56.0

# %%
df.iloc[197:200,0:3]
# Out:
#       id    age  gender
# 197  271  21796       2
# 198  272  15212       2
# 199  275  18825       1

# %%
df.drop(2)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# 5          8  21914       1     151    67.0    120     80            2     2
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.drop(1,axis=0)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# 5          8  21914       1     151    67.0    120     80            2     2
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.drop("age",axis=1)
# Out:
#           id  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0          0       2     168    62.0    110     80            1     1      0
# 1          1       1     156    85.0    140     90            3     1      0
# 2          2       1     165    64.0    130     70            3     1      0
# 3          3       2     169    82.0    150    100            1     1      0
# 4          4       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  99993       2     168    76.0    120     80            1     1      1
# 69996  99995       1     158   126.0    140     90            2     2      0
# 69997  99996       2     183   105.0    180     90            3     1      0
# 69998  99998       1     163    72.0    135     80            1     2      0
# 69999  99999       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# ...

# %%
df.isnull().sum() #it shows null values
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df.dropna() #dropping missing data by default row wise
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.dropna(axis=0) #dropping missing data by selecting row wise
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.dropna(axis=1)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.dropna(axis=1,inplace=True)
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.dropna(how="any") #rows containing null values will be deleted(their is no null values in the given data)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df2=pd.read_csv(r"C:\Users\Akhila\AI\cardio_train.csv")
df2
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df2.dropna(subset=["weight","age"]) #columnwise nulkl values will be deleted
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df2["height"].isnull().sum() #null values detection
# Out:
# 0

# %%
df2.interpolate()
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
import seaborn as sn
import matplotlib.pyplot as plt
smoke=[0,1,2,9]                      #line plot
ap_lo=[125,213,231,123]
plt.plot(smoke,ap_lo)

# %%
plt.scatter(smoke,ap_lo)

# %%
import seaborn as sn
import matplotlib.pyplot as plt
smoke=[0,1,2,9]                      #line plot
ap_lo=[125,213,231,123]
plt.plot(smoke,ap_lo)
plt.title("smoke vs ap_lo")
# Out:
# Text(0.5, 1.0, 'smoke vs ap_lo')

# %%
import seaborn as sn
import matplotlib.pyplot as plt
ap_hi=[110,130,140,150]                      #plot will plots the given data
age=[1843,2345,1256,3425]                    #xlabel and ylabel are used to give the titles for the graph
plt.plot(ap_hi,age)                           #title is used to give the title for the graph
plt.scatter(ap_hi,age)
plt.xlabel("ap_hi")
plt.ylabel("age")
plt.title("ap_hi vs age")
# Out:
# Text(0.5, 1.0, 'ap_hi vs age')

# %%
plt.title("ap_hi vs age",fontsize=25)             #font size is used to increase the size of the title
# Out:
# Text(0.5, 1.0, 'ap_hi vs age')

# %%
df3=pd.DataFrame({"alco":[29,16,2,12],"cholesterol":[2,1,0,5]})
df3

# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv(r"C:\Users\Akhila\AI\cardio_train.csv") 
sns.lineplot(x="aloc",y="cholesterol")

# %%
import seaborn as sn
import matplotlib.pyplot as plt
smoke=[0,1,2,9]                      #line plot
ap_lo=[125,213,231,123]
plt.plot(smoke,ap_lo)
plt.scatter(smoke,ap_lo,marker='*')

# %%
import seaborn as sn
import matplotlib.pyplot as plt
ap_hi=[110,130,140,150]                      #plot will plots the given data
age=[1843,2345,1256,3425]                    #xlabel and ylabel are used to give the titles for the graph
plt.plot(ap_hi,age)                           #title is used to give the title for the graph
plt.scatter(ap_hi,age)
plt.xlabel("ap_hi")
plt.ylabel("age")
plt.title("ap_hi vs age")
clr=['r','b','g','c']

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.lmplot(x="age",y="ap_hi",data=df2)

# %%
import sklearn 
from sklearn.linear_model import linearRegression
lin_reg=linearRegression()
lin_reg.fit(df[["age"]],df2[["ap_hi"]])

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv(r"C:\Users\Akhila\AI\cardio_train.csv") 
plt.bar(df["alco"],df["cholesterol"])
# Out:
# <BarContainer object of 70000 artists>

# %%
smoke=[1,2,3,4]
alco=[100,200.300,400]
cholesterol=[0,1,2,3]
plt.pie(smoke)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e92eca1c70>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, ''),
#   Text(0.33991867422268784, 1.0461621742897658, ''),
#   Text(-1.0461621902025062, 0.3399186252483017, ''),
#   Text(0.3399188211458418, -1.0461621265515308, '')])

# %%
import matplotlib.pyplot as plt
smoke=[1,2,3,4]
alco=[100,200.300,400]
cholesterol=[0,1,2,3]
plt.pie(smoke)
plt.pie(smoke,shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e92ed66f90>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, ''),
#   Text(0.33991867422268784, 1.0461621742897658, ''),
#   Text(-1.0461621902025062, 0.3399186252483017, ''),
#   Text(0.3399188211458418, -1.0461621265515308, '')])

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\Akhila\AI\cardio_train.csv")
df['age_Years']=df['age']
sns.histplot(df['age_Years'],kde=True)
plt.title('Age Distribution')
plt.xlabel('Age (years)')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df4=pd.read_csv(r"C:\Users\Akhila\AI\cardio_train.csv")
sns.boxplot(x='gender',y='height',data=df)
plt.title('Height by Gender')
plt.ylabel('gender')
plt.ylabel('Height (cm)')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df5=pd.read_csv(r"C:\Users\Akhila\AI\cardio_train.csv")
sns.boxplot(x='gender',y='weight',data=df5)
plt.title('weight by gender')
plt.xlabel('gender')
plt.ylabel('weight (kg)')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv(r"C:\Users\Akhila\AI\cardio_train.csv")
print(data.columns)
columns_to_plot=['age','height','weight','ap_hi','ap_lo','cardio']
missing_columns=[col for col in columns_to_plot if col not in data.columns]
if missing_columns:
  print(missing_columns)
else:
  data['age_years']=data['age']
  columns_to_plot[0]='age_years'
  sns.pairplot(data[columns_to_plot],hue='cardio')
  plt.show()
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
df7=pd.read_csv(r"C:\Users\Akhila\AI\cardio_train.csv") #data accessing
df7
corr=df7.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr,annot=True,cmap='coolwarm',fmt='2f')
plt.title('correlation Matrix')
plt.show()

# %%
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from  sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from  sklearn.neighbors import KNeighborsClassifier
from  sklearn.tree import DecisionTreeClassifier
from  sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from  sklearn .metrics import accuracy_score

df7=pd.read_csv(r"C:\Users\Akhila\AI\cardio_train.csv") 

df7['age_years']=df7['age']
x=df7[['age_years','height','weight','ap_hi','ap_lo','gluc','smoke','active']]
y=df7['cardio']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

svm_model=SVC()
svm_model.fit(x_train,y_train)
y_pred_svm=svm_model.predict(x_test)
accuracy_svm=accuracy_score(y_test,y_pred_svm)
print(f"SVM Accuracy: {accuracy_svm:.2f}")

knn_model=KNeighborsClassifier()
knn_model.fit(x_train,y_train)
y_pred_knn=knn_model.predict(x_test)
accuracy_knn=accuracy_score(y_test,y_pred_knn)
print(f"KNN Accuracy:{accuracy_knn:.2f}")

dt_model=DecisionTreeClassifier()
dt_model.fit(x_train,y_train)
y_pred_dt=dt_model.predict(x_test)
accuracy_dt=accuracy_score(y_test,y_pred_dt)
print(f"decision tree accuracy:{accuracy_dt:.2f}") 

lr_model=LogisticRegression(max_iter=1000)
lr_model.fit(x_train,y_train)
y_pred_lr=lr_model.predict(x_test)
accuracy_lr=accuracy_score(y_test,y_pred_lr)
print(f"Logostic Regression Accuracy: {accuracy_lr:.2f}")

rf_model=RandomForestClassifier()
rf_model.fit(x_train,y_train)
y_pred_rf=rf_model.predict(x_test)
accuracy_rf=accuracy_score(y_test,y_pred_rf)
print(f"Random Forest Accuracy: {accuracy_rf:.2f}")

# %%
predict=model.predict(x_train)
Accuracy=accuracy_score(predict,y_train)
print(Accuracy)

# %%
predict=model.predict(x_test)
Accuracy=accuracy_score(predict,y_test)
print(Accuracy)

# %%
import  pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

df=pd.read_csv(r"C:\Users\Akhila\AI\cardio_train.csv") 

df['age_years']=df['age']
x=df[['age_years','height','weight','ap_hi','ap_lo','cholesterol','gluc','smoke','alco','active']]
y=df['cardio']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

svm_model=SVC(kernel='linear',random_state=42)

svm_model.fit(x_train,y_train)

y_pred=svm_model.predict(x_test)

accuracy=accuracy_score(y_test,y_pred)
print(f"Classification Report:")
print(classification_report(y_test,y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test,y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.81      0.75     10461
#            1       0.77      0.64      0.70     10539
#
#     accuracy                           0.73     21000
#    macro avg       0.73      0.73      0.72     21000
# weighted avg       0.73      0.73      0.72     21000
#
# Confusion Matrix:
# [[8473 1988]
#  [3778 6761]]

# %%
#RESULT
'''
    class0(no disease) was more accurately predict by the model with higher recall(0.81) and a decent F1-score(0.75)

    class1(with disease) had slightly lower recall(0.64) and F1-score(0.70),indicating the model had more difficult correctly
    identifying all disease cases

    the overall performance of the model is decent with an accuracy of 0.73,but there a slight bias towards predicting the absence
    of disease more accurately than predicting the presence of disease .'''

# %%
print(x_train)
# Out:
# [[ 0.38817489 -0.5308834  -0.70816849 ... -0.39474649 -0.31319072
#    0.49466891]
#  [ 1.30846829  0.32314728 -0.63861364 ...  3.11124914 -0.31319072
#   -2.02155415]
#  [ 1.34652706 -0.5308834  -0.56905879 ... -0.39474649 -0.31319072
#    0.49466891]
#  ...
#  [ 1.67245587  0.56715605 -0.01261999 ... -0.39474649 -0.31319072
#    0.49466891]
#  [-0.49851342  0.32314728 -0.29083939 ... -0.39474649 -0.31319072
#   -2.02155415]
#  [-1.75890645  1.54319112 -0.70816849 ... -0.39474649 -0.31319072
#    0.49466891]]
